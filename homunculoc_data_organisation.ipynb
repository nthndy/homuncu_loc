# %% [markdown]
# # homuncu_loc data organisation

# %%
import napari
from skimage import io
import btrack
import os
from tqdm.auto import tqdm
from homuncu_loc import dataio
import os, glob
import shutil
import pandas as pd
from collections import defaultdict

# %% [markdown]
# # Check to see how many images have sc analyses etc

# %%
root_dir = '/run/user/30046150/gvfs/smb-share:server=data2.thecrick.org,share=lab-gutierrezm/home/shared/Lung on Chip/homuncu_loc_image_analysis/'

# %%
results = dataio.sc_analysis_progress_check(root_dir)

# %%
results
# Out:
#       ID          expt_type has_sc_analyses  \
# 0    112          iAT1_iAT2               1
# 1    113          iAT1_iAT2               1
# 2    121          iAT1_iAT2               1
# 3    122          iAT1_iAT2               1
# 4    123          iAT1_iAT2               1
# 5    194          iAT1_iAT2               2
# 6    195          iAT1_iAT2               2
# 7    196          iAT1_iAT2               2
# 8    235          iAT1_iAT2               1
# 9    236          iAT1_iAT2               1
# 10   237          iAT1_iAT2               1
# 11   244          iAT1_iAT2               1
# 12   245          iAT1_iAT2               1
# 13   246          iAT1_iAT2               1
# 14   284          iAT1_iAT2               1
# 15   286          iAT1_iAT2               1
# 16   287          iAT1_iAT2               1
# 17   292          iAT1_iAT2               1
# 18   295          iAT1_iAT2               2
# 19   298          iAT1_iAT2               1
# 20  1306  macroph_iAT1_iAT2           False
# 21  1307  macroph_iAT1_iAT2               5
# 22  1308  macroph_iAT1_iAT2               5
# 23  1309  macroph_iAT1_iAT2               3
# 24  1310  macroph_iAT1_iAT2               3
# 25  1311  macroph_iAT1_iAT2               5
# 26  1313  macroph_iAT1_iAT2               4
# 27  1314  macroph_iAT1_iAT2               6
# 28  1315  macroph_iAT1_iAT2               7
# 29  1316  macroph_iAT1_iAT2               4
# 30  1317  macroph_iAT1_iAT2               3
# 31  1318  macroph_iAT1_iAT2               4
# 32  1319  macroph_iAT1_iAT2               4
# 33  1320  macroph_iAT1_iAT2               7
# 34  1324  macroph_iAT1_iAT2               3
# 35  1325  macroph_iAT1_iAT2               3
# 36  1340  macroph_iAT1_iAT2               3
# 37  1341  macroph_iAT1_iAT2           False
# 38  1342  macroph_iAT1_iAT2           False
# 39  1343  macroph_iAT1_iAT2           False
# 40  1344  macroph_iAT1_iAT2           False
# 41  1361  macroph_iAT1_iAT2               3
# 42  1362  macroph_iAT1_iAT2               3
# 43  1363  macroph_iAT1_iAT2               3
# 44  1364  macroph_iAT1_iAT2               3
# 45  1365  macroph_iAT1_iAT2               3
# 46  1434          iAT1_iAT2               4
# 47  1441          iAT1_iAT2               4
# 48  1444          iAT1_iAT2               4
#
#                                              sc_types  has_tif  has_vsi  \
# 0                                [_z_tracks_masks.h5]     True     True
# 1                                [_z_tracks_masks.h5]     True     True
# 2                                [_z_tracks_masks.h5]     True     True
# 3                                [_z_tracks_masks.h5]     True     True
# 4                                [_z_tracks_masks.h5]     True     True
# 5           [_z_tracks_masks.h5, _z_tracks_masks.csv]     True     True
# 6           [_z_tracks_masks.csv, _z_tracks_masks.h5]     True     True
# 7           [_z_tracks_masks.csv, _z_tracks_masks.h5]     True     True
# 8                                [_z_tracks_masks.h5]     True     True
# 9                                [_z_tracks_masks.h5]     True     True
# 10                               [_z_tracks_masks.h5]     True     True
# 11                               [_z_tracks_masks.h5]     True     True
# 12                               [_z_tracks_masks.h5]     True     True
# 13                               [_z_tracks_masks.h5]     True     True
# 14                               [_z_tracks_masks.h5]     True     True
# 15                               [_z_tracks_masks.h5]     True     True
# 16                               [_z_tracks_masks.h5]     True     True
# 17                               [_z_tracks_masks.h5]     True     True
# 18  [_z_tracks_masks.h5, _constrained_z_tracks_mas...     True     True
# 19                               [_z_tracks_masks.h5]     True     True
# 20                                              False     True     True
# 21  [_sc_data.h5, _z_tracks_masks_d100.h5, _sc_res...     True     True
# 22  [_sc_data_subset.csv, _z_tracks_masks_d100.h5,...     True     True
# 23  [_sc_results.csv, _z_tracks_masks_d100.h5, _z_...     True     True
# 24  [_sc_results.csv, _z_tracks_masks.h5, _z_track...     True     True
# 25  [_sc_data_subset.csv, _sc_data.h5, _z_tracks_m...     True     True
# 26  [_z_tracks_masks_d100.h5, _sc_results.csv, _z_...     True     True
# 27  [_sc_results.csv, _z_tracks_masks_d100.h5, _sc...     True     True
# 28  [_sc_data.h5, _sc_results.csv, _z_tracks_masks...     True     True
# 29  [_sc_results.csv, _z_tracks_masks.h5, _z_track...     True     True
# 30  [_sc_results.csv, _z_tracks_masks.h5, _z_track...     True     True
# 31  [_z_tracks_masks_no_mtb_measure.h5, _sc_result...     True     True
# 32  [_sc_results.csv, _z_tracks_masks_d100.h5, _z_...     True     True
# 33  [_sc_data.h5, _z_tracks_masks_d100.h5, _z_trac...     True     True
# 34  [_z_tracks_masks_d100.h5, _z_tracks_masks.h5, ...     True     True
# 35  [_z_tracks_masks_d100.h5, _z_tracks_masks.h5, ...     True     True
# 36  [_sc_results.csv, _z_tracks_masks.h5, _z_track...     True     True
# 37                                              False     True     True
# 38                                              False     True     True
# 39                                              False     True     True
# 40                                              False     True     True
# 41  [_sc_results.csv, _z_tracks_masks.h5, _z_track...     True     True
# 42  [_sc_results.csv, _z_tracks_masks_d100.h5, _z_...     True     True
# 43  [_z_tracks_masks.h5, _z_tracks_masks_d100.h5, ...     True     True
# 44  [_sc_results.csv, _z_tracks_masks_d100.h5, _z_...     True     True
# 45  [_z_tracks_masks_d100.h5, _sc_results.csv, _z_...     True     True
# 46  [_sc_results.csv, _sc_data.h5, _z_tracks_masks...     True     True
# 47  [_sc_results.csv, _sc_data_subset.csv, _sc_dat...     True     True
# 48  [_sc_results.csv, _sc_data_subset.csv, _sc_dat...     True     True
#
#     has_metadata                                     image_location  \
# 0           True  /run/user/30046150/gvfs/smb-share:server=data2...
# 1           True  /run/user/30046150/gvfs/smb-share:server=data2...
# 2           True  /run/user/30046150/gvfs/smb-share:server=data2...
# 3           True  /run/user/30046150/gvfs/smb-share:server=data2...
# 4           True  /run/user/30046150/gvfs/smb-share:server=data2...
# 5           True  /run/user/30046150/gvfs/smb-share:server=data2...
# 6           True  /run/user/30046150/gvfs/smb-share:server=data2...
# 7           True  /run/user/30046150/gvfs/smb-share:server=data2...
# 8           True  /run/user/30046150/gvfs/smb-share:server=data2...
# 9           True  /run/user/30046150/gvfs/smb-share:server=data2...
# 10          True  /run/user/30046150/gvfs/smb-share:server=data2...
# 11          True  /run/user/30046150/gvfs/smb-share:server=data2...
# 12          True  /run/user/30046150/gvfs/smb-share:server=data2...
# 13          True  /run/user/30046150/gvfs/smb-share:server=data2...
# 14          True  /run/user/30046150/gvfs/smb-share:server=data2...
# 15          True  /run/user/30046150/gvfs/smb-share:server=data2...
# 16          True  /run/user/30046150/gvfs/smb-share:server=data2...
# 17          True  /run/user/30046150/gvfs/smb-share:server=data2...
# 18          True  /run/user/30046150/gvfs/smb-share:server=data2...
# 19          True  /run/user/30046150/gvfs/smb-share:server=data2...
# 20          True  /run/user/30046150/gvfs/smb-share:server=data2...
# 21          True  /run/user/30046150/gvfs/smb-share:server=data2...
# 22          True  /run/user/30046150/gvfs/smb-share:server=data2...
# 23          True  /run/user/30046150/gvfs/smb-share:server=data2...
# 24          True  /run/user/30046150/gvfs/smb-share:server=data2...
# 25          True  /run/user/30046150/gvfs/smb-share:server=data2...
# 26          True  /run/user/30046150/gvfs/smb-share:server=data2...
# 27          True  /run/user/30046150/gvfs/smb-share:server=data2...
# 28          True  /run/user/30046150/gvfs/smb-share:server=data2...
# 29          True  /run/user/30046150/gvfs/smb-share:server=data2...
# 30          True  /run/user/30046150/gvfs/smb-share:server=data2...
# 31          True  /run/user/30046150/gvfs/smb-share:server=data2...
# 32          True  /run/user/30046150/gvfs/smb-share:server=data2...
# 33          True  /run/user/30046150/gvfs/smb-share:server=data2...
# 34          True  /run/user/30046150/gvfs/smb-share:server=data2...
# 35          True  /run/user/30046150/gvfs/smb-share:server=data2...
# 36          True  /run/user/30046150/gvfs/smb-share:server=data2...
# 37          True  /run/user/30046150/gvfs/smb-share:server=data2...
# 38          True  /run/user/30046150/gvfs/smb-share:server=data2...
# 39          True  /run/user/30046150/gvfs/smb-share:server=data2...
# 40          True  /run/user/30046150/gvfs/smb-share:server=data2...
# 41          True  /run/user/30046150/gvfs/smb-share:server=data2...
# 42          True  /run/user/30046150/gvfs/smb-share:server=data2...
# 43          True  /run/user/30046150/gvfs/smb-share:server=data2...
# 44          True  /run/user/30046150/gvfs/smb-share:server=data2...
# 45          True  /run/user/30046150/gvfs/smb-share:server=data2...
# 46          True  /run/user/30046150/gvfs/smb-share:server=data2...
# 47          True  /run/user/30046150/gvfs/smb-share:server=data2...
# 48          True  /run/user/30046150/gvfs/smb-share:server=data2...
#
#                                              image_fn
# 0   20x_21-12-031B_A12456_Multichannel Z-Stack_202...
# 1   20x_21-12-031B_A12456_Multichannel Z-Stack_202...
# 2   20x_21-12-031B_A12456_Multichannel Z-Stack_202...
# 3   20x_21-12-031B_A12456_Multichannel Z-Stack_202...
# 4   20x_21-12-031B_A12456_Multichannel Z-Stack_202...
# 5   20x_21-12-029A_A3456_Multichannel Z-Stack_2022...
# 6   20x_21-12-029A_A3456_Multichannel Z-Stack_2022...
# 7   20x_21-12-029A_A3456_Multichannel Z-Stack_2022...
# 8   20x_21-12-028A_A23456_Multichannel Z-Stack_202...
# 9   20x_21-12-028A_A23456_Multichannel Z-Stack_202...
# 10  20x_21-12-028A_A23456_Multichannel Z-Stack_202...
# 11  20x_21-12-028A_A23456_Multichannel Z-Stack_202...
# 12  20x_21-12-028A_A23456_Multichannel Z-Stack_202...
# 13  20x_21-12-028A_A23456_Multichannel Z-Stack_202...
# 14  20x_21-12-029B_A12346_Multichannel Z-Stack_202...
# 15  20x_21-12-029B_A12346_Multichannel Z-Stack_202...
# 16  20x_21-12-029B_A12346_Multichannel Z-Stack_202...
# 17  20x_21-12-029B_A12346_Multichannel Z-Stack_202...
# 18  20x_21-12-029B_A12346_Multichannel Z-Stack_202...
# 19  20x_21-12-029B_A12346_Multichannel Z-Stack_202...
# 20  20230705_40X_23-01-005A3_Multichannel Z-Stack_...
# 21  20230705_40X_23-01-005A3_Multichannel Z-Stack_...
# 22  20230705_40X_23-01-005A3_Multichannel Z-Stack_...
# 23  20230705_40X_23-01-005A3_Multichannel Z-Stack_...
# 24  20230705_40X_23-01-005A3_Multichannel Z-Stack_...
# 25  20230705_40X_23-01-005A3_Multichannel Z-Stack_...
# 26  20230707_40X_23-01-001A3_Multichannel Z-Stack_...
# 27  20230707_40X_23-01-001A3_Multichannel Z-Stack_...
# 28  20230707_40X_23-01-001A3_Multichannel Z-Stack_...
# 29  20230707_40X_23-01-001A3_Multichannel Z-Stack_...
# 30  20230707_40X_23-01-001A3_Multichannel Z-Stack_...
# 31  20230707_40X_23-01-001A3_Multichannel Z-Stack_...
# 32  20230707_40X_23-01-001A3_Multichannel Z-Stack_...
# 33  20230707_40X_23-01-001A3_Multichannel Z-Stack_...
# 34  20230707_40X_23-01-005A3_Multichannel Z-Stack_...
# 35  20230707_40X_23-01-005A3_Multichannel Z-Stack_...
# 36  20230714_20X_23-02-104A4_Multichannel Z-Stack_...
# 37  20230714_20X_23-02-104A4_Multichannel Z-Stack_...
# 38  20230714_20X_23-02-104A4_Multichannel Z-Stack_...
# 39  20230714_20X_23-02-104A4_Multichannel Z-Stack_...
# 40  20230714_20X_23-02-104A4_Multichannel Z-Stack_...
# 41  20230718_20X_23-02-104B2_Multichannel Z-Stack_...
# 42  20230718_20X_23-02-104B2_Multichannel Z-Stack_...
# 43  20230718_20X_23-02-104B2_Multichannel Z-Stack_...
# 44  20230718_20X_23-02-104B2_Multichannel Z-Stack_...
# 45  20230718_20X_23-02-104B2_Multichannel Z-Stack_...
# 46  20230801_20X_23-03-011B5_DAPI_NKX2-1_PDPN_ZO-1...
# 47  20230801_20X_23-03-002A5_DAPI_NKX201_PDPN_ZO-1...
# 48  20230801_20X_23-03-002A6_DAPI_SP-C_PDPN_ZO-1_M...

# %%
results['sc_types'].iloc[1]
# Out:
# ['_z_tracks_masks_no_mtb_measure.h5',
#  '_sc_results.csv',
#  '_z_tracks_masks.h5',
#  '_z_tracks_masks_d100.h5']

# %%
results.to_csv('/home/dayn/analysis/homuncu_loc/data_repository.csv')

# %% [markdown]
# ### Create empty directory structure

# %%
# Specify the base directory where you want to create the structure
base_dir = "/run/user/30046150/gvfs/smb-share:server=data2.thecrick.org,share=lab-gutierrezm/home/shared/Lung on Chip/homuncu_loc_image_analysis/another_attempt_at_new_org"

# Call the function to create the structure
dataio.create_experiment_structure(base_dir)

print("Directory structure created successfully!")
# Out:
# Directory structure created successfully!

# %% [markdown]
# ### Add files into directory structure using information from data organisation spreadsheet.

# %%
# Read the CSV data
csv_path = "/home/dayn/Downloads/Untitled spreadsheet - Sheet1.csv"
df = pd.read_csv(csv_path)

# Define the base directory where the files will be organized
source_dir = "/run/user/30046150/gvfs/smb-share:server=data2.thecrick.org,share=lab-gutierrezm/home/shared/Lung on Chip/homuncu_loc_image_analysis/old_organisation"
base_dir = "/run/user/30046150/gvfs/smb-share:server=data2.thecrick.org,share=lab-gutierrezm/home/shared/Lung on Chip/homuncu_loc_image_analysis/new_organisation"  # Directory for copied files

# Loop through the rows in the DataFrame
for index, row in tqdm(df.iterrows(), total = len(df)):
    filename = row["basename"].split('.')[0]
    markers = row["Markers"].replace('-', '_')
    n_cell_types = row["N cell types"]
    
    # Construct the source path by searching for the filename
    for root, dirs, files in os.walk(source_dir):
        for file in files:
            if filename in file:
                source_path = os.path.join(root, file)
                print(f'Moving source filename: {source_path}')
                if n_cell_types == 2:
                    if ('.h5' in file) or ('.hdf5' in file) or ('.csv' in file) or ('.xlsx' in file) or ('.prism' in file): 
                        target_dir = os.path.join(base_dir, "iAT1_iAT2_experiments", markers, 'sc_analyses')
                    else:
                        target_dir = os.path.join(base_dir, "iAT1_iAT2_experiments", markers, 'images')
                elif n_cell_types == 4:
                    if ('.h5' in file) or ('.hdf5' in file) or ('.csv' in file) or ('.xlsx' in file) or ('.prism' in file): 
                        target_dir = os.path.join(base_dir, "iAT1_iAT2_iVEC_macrophage_experiments", markers, 'sc_analyses')
                    else:
                        target_dir = os.path.join(base_dir, "iAT1_iAT2_iVEC_macrophage_experiments", markers, 'images')
                else:
                    if ('.h5' in file) or ('.hdf5' in file) or ('.csv' in file) or ('.xlsx' in file) or ('.prism' in file): 
                        target_dir = os.path.join(base_dir, "iAT1_iAT2_iVEC_experiments", markers, 'sc_analyses')
                    else:
                        target_dir = os.path.join(base_dir, "iAT1_iAT2_iVEC_experiments", markers, 'images')

               # Create the target directory if it doesn't exist
                os.makedirs(target_dir, exist_ok=True)

                # create destination path 
                dest_path = os.path.join(target_dir, file)

                if os.path.exists(dest_path):
                    continue
                
                try:# Copy the file to the target directory
                    shutil.move(source_path, dest_path)
                except:
                    print(f'Error: {source_path}')
                
        # now copy directories that match the original filename
        for dir in dirs:
            if filename in dir:
                source_path = os.path.join(root, dir)
                print(f'Moving source directory: {source_path}')
                if n_cell_types == 2:
                    target_dir = os.path.join(base_dir, "iAT1_iAT2_experiments", markers, 'images')
                elif n_cell_types == 4:
                    # if "macrophage" in markers:
                    target_dir = os.path.join(base_dir, "iAT1_iAT2_iVEC_macrophage_experiments", markers, 'images')
                else:
                    target_dir = os.path.join(base_dir, "iAT1_iAT2_iVEC_experiments", markers, 'images')
    
        
                # Create the target directory if it doesn't exist
                os.makedirs(target_dir, exist_ok=True)

                # create destination path 
                dest_path = os.path.join(target_dir, dir)
                if os.path.exists(dest_path):
                    continue
                try:
                    # Copy the file to the target directory
                    shutil.move(source_path, dest_path)
                except:
                    print(f'Error: {source_path}')
# Out:
#   0%|          | 0/77 [00:00<?, ?it/s]
# Moving source filename: /run/user/30046150/gvfs/smb-share:server=data2.thecrick.org,share=lab-gutierrezm/home/shared/Lung on Chip/homuncu_loc_image_analysis/old_organisation/results_(old_organisation, currently reviewing)/run0/DAPI-SPC-PDPN-ZO1/Day14_breath/20x_21-12-029B_A12346_Multichannel Z-Stack_20220819_295_z_tracks_masks.h5
# Moving source filename: /run/user/30046150/gvfs/smb-share:server=data2.thecrick.org,share=lab-gutierrezm/home/shared/Lung on Chip/homuncu_loc_image_analysis/old_organisation/Job_1/DAPI-SPC-PDPN-ZO1/Day14_breath/20x_21-12-029B_A12346_Multichannel Z-Stack_20220819_295.vsi
# Moving source filename: /run/user/30046150/gvfs/smb-share:server=data2.thecrick.org,share=lab-gutierrezm/home/shared/Lung on Chip/homuncu_loc_image_analysis/old_organisation/Job_1/DAPI-SPC-PDPN-ZO1/Day14_breath/20x_21-12-029B_A12346_Multichannel Z-Stack_20220819_295.tif
# Moving source filename: /run/user/30046150/gvfs/smb-share:server=data2.thecrick.org,share=lab-gutierrezm/home/shared/Lung on Chip/homuncu_loc_image_analysis/old_organisation/Job
/run/user/30046150/gvfs/smb-share:server=data2.thecrick.org,share=lab-gutierrezm/home/shared/Lung on Chip/homuncu_loc_image_analysis/old_organisation/Job_Mtb area/run1_23-01-001_23-01-005/2h pi_new/_20230705_40X_23-01-001B3_Multichannel Z-Stack_20230705_1299_
# Moving source filename: /run/user/30046150/gvfs/smb-share:server=data2.thecrick.org,share=lab-gutierrezm/home/shared/Lung on Chip/homuncu_loc_image_analysis/old_organisation/Job_Mtb area/run1_23-01-001_23-01-005/2h pi_new/20230705_40X_23-01-001B3_Multichannel Z-Stack_20230705_1300.vsi
# Moving source directory: /run/user/30046150/gvfs/smb-share:server=data2.thecrick.org,share=lab-gutierrezm/home/shared/Lung on Chip/homuncu_loc_image_analysis/old_organisation/Job_Mtb area/run1_23-01-001_23-01-005/2h pi_new/_20230705_40X_23-01-001B3_Multichannel Z-Stack_20230705_1300_

# %% [markdown]
# ###

# %% [markdown]
# ### Check to see if all files transferred.

# %%
# Define the base directory where the files will be organized
dir1 = "/run/user/30046150/gvfs/smb-share:server=data2.thecrick.org,share=lab-gutierrezm/home/shared/Lung on Chip/homuncu_loc_image_analysis/old_organisation"
dir2 = "/run/user/30046150/gvfs/smb-share:server=data2.thecrick.org,share=lab-gutierrezm/home/shared/Lung on Chip/homuncu_loc_image_analysis/new_organisation"  # Directory for copied files


_, _, missing_files = dataio.compare_directories_recursive(dir1, dir2)
print("Files in the first directory that are missing in the second directory:")
for file in missing_files:
    print(file)
    print('')
# Out:
# Files in the first directory that are missing in the second directory:

# %% [markdown]
# ### Check to see if any files were corrupted in the transfer
#
# Might happen if the connection times out or if the image files weren't properly transferred in the first place

# %%
# Example usage
directory_to_search = "/run/user/30046150/gvfs/smb-share:server=data2.thecrick.org,share=lab-gutierrezm/home/shared/Lung on Chip/homuncu_loc_image_analysis"
empty_files_list = dataio.find_empty_files(directory_to_search)

for file_path in empty_files_list:
    print(f"Empty file found: {file_path}")
# Out:
# Empty file found: /run/user/30046150/gvfs/smb-share:server=data2.thecrick.org,share=lab-gutierrezm/home/shared/Lung on Chip/homuncu_loc_image_analysis/iAT1_iAT2_iVEC_macrophage_experiments/DAPI_ZO1_CD16_MTB/images/20230705_40X_23-01-001B3_Multichannel Z-Stack_20230705_1299.vsi
# Empty file found: /run/user/30046150/gvfs/smb-share:server=data2.thecrick.org,share=lab-gutierrezm/home/shared/Lung on Chip/homuncu_loc_image_analysis/iAT1_iAT2_iVEC_macrophage_experiments/DAPI_ZO1_CD16_MTB/images/20230705_40X_23-01-001B3_Multichannel Z-Stack_20230705_1300.vsi
# Empty file found: /run/user/30046150/gvfs/smb-share:server=data2.thecrick.org,share=lab-gutierrezm/home/shared/Lung on Chip/homuncu_loc_image_analysis/iAT1_iAT2_iVEC_macrophage_experiments/DAPI_ZO1_CD16_MTB/images/20230705_40X_23-01-001B3_Multichannel Z-Stack_20230705_1298.vsi
# Empty file found: /run/user/30046150/gvfs/smb-share:server=data2.thecrick.org,share=lab-gutierrezm/home/shared/Lung on Chip/homuncu_loc_image_analysis/iAT1_iAT2_experiments/DAPI_NKX21_PDPN_ZO1/images/20230801_20X_23-03-011B5_DAPI_NKX2-1_PDPN_ZO-1_Multichannel Z-Stack_20230801_1435.vsi

# %% [markdown]
# ### Check to see what images have what analyses in them.

# %%
import os

def analyze_images(root_dir="homuncu_loc_image_analysis"):
    """
    Analyze .tif images to check for corresponding .vsi images and metadata directories.

    Parameters:
    - root_dir (str): The root directory to start the search from.

    Returns:
    - list: A list of dictionaries containing details about each .tif image.
    """

    results = []

    # Traverse the specified directory structure
    for root, dirs, files in os.walk(root_dir):
        for file in files:
            if file.endswith('.tif'):
                tif_path = os.path.join(root, file)
                tif_basename = os.path.splitext(file)[0]
                tif_ID = tif_basename.split('_')[-1].split('.tif')[0]

                # Check for corresponding .vsi file
                vsi_exists = os.path.exists(os.path.join(root, tif_basename + '.vsi'))

                # Check for corresponding metadata directory
                metadata_dir = os.path.join(os.path.dirname(root), tif_basename)
                metadata_exists = os.path.isdir(metadata_dir) and any(f for f in os.listdir(metadata_dir) if f.startswith('metadata'))

                results.append({
                    "tif_path": tif_path,
                    "tif_basename": tif_basename,
                    "has_vsi": vsi_exists,
                    "has_metadata": metadata_exists
                })

    results = pd.DataFrame(data = results)

    return results
